# %% [markdown]
# ## Corpus

# %%
from pykhmernlp.corpus import km_words

km_words = km_words()
print(f"Length of Khmer words {len(km_words)}")
print(km_words[:100])
# Out:
# Length of Khmer words 81028
# ['ក', 'កក', 'កកកុញ', 'កកកុះ', 'កកឈាម', 'កកទឹកកកដី', 'កករ', 'កករចិត្ត', 'កកស', 'កកស្ទះ', 'កកា', 'កកាត', 'កកាប', 'កកាយ', 'កកាយកកូរ', 'កកិច', 'កកិចកកុច', 'កកិដ', 'កកិត', 'កកិបកកុប', 'កកិល', 'កកិលចូលជិត', 'កកី', 'កកុក', 'កកុច', 'កកុធ', 'កកុធភណ្ឌ', 'កកុសន្ធៈ', 'កកូន', 'កកូរ', 'កកូរកកាយ', 'កកួរ', 'កកើត', 'កកេបកកាប', 'កកេរ', 'កកេរឆ្អឹង', 'កកេះ', 'កកេះកកាយ', 'កកែ', 'កកែកកកោក', 'កកែកករ', 'កកែងកកោង', 'កកែងកោង', 'កកែប', 'កកែបក្របី', 'កកែបគោ', 'កកែះ', 'កកោក', 'កកោកកកាក', 'កកោស', 'កកោះ', 'កក់', 'កក់ក្ដៅ', 'កក់ក្តៅ', 'កក់ក្បាល', 'កក់ខែ', 'កក់ចែងម៉ែង', 'កក់ជ្រុង', 'កក់មូល', 'កក់លុយ', 'កក់សក់', 'កក៌ដ', 'កក្កដ', 'កក្កដា', 'កក្កដៈ', 'កក្ខលភាព', 'កក្ងិច', 'កក្ងៀក', 'កក្ងៀង', 'កក្ដដ', 'កក្តិក', 'កក្រិត', 'កក្រូស', 'កក្រើក', 'កក្រើកទឹកកក្រើកដី', 'កក្រើករំជួល', 'កក្រើករំពើក', 'កក្រោក', 'កក្រោះ', 'កក្លាក់', 'កក្លិកកក្លាក់', 'កក្វិសកក្វាស់', 'កក្សា', 'កក្អម', 'កក្អាក', 'កក្អាកកក្អាយ', 'កក្អាកក្អាយ', 'កក្អាយ', 'កក្អិច', 'កក្អិចកក្អៀក', 'កក្អិល', 'កក្អឹក', 'កក្អឹកកក្អិល', 'កក្អៀក', 'កក្អៀកកក្អាយ', 'កក្អៀច', 'កក្អែ', 'កខក់', 'កខិក', 'កខិកកខក់']

# %%
from pykhmernlp.corpus import en_words

en_words = en_words()

print(f"Length of English words {len(en_words)}")
print(en_words[:100])
# Out:
# Length of English words 235892
# ['elcaja', 'problockade', 'chalkiness', 'advise', 'steeplelike', 'strumpetry', 'zoetropic', 'earthborn', 'enfetter', 'Odontophoridae', 'oilfish', 'offertorial', 'tutorless', 'metallify', 'stalklike', 'calumniousness', 'epidermatoid', 'Palamedea', 'Gradgrind', 'thyroprivic', 'interfamily', 'Jesuitess', 'aryepiglottic', 'Babbie', 'clearedness', 'revenger', 'exudative', 'Chamorro', 'herbman', 'perimysial', 'eutomous', 'westernization', 'Tarsonemidae', 'suppedaneum', 'agglutinize', 'dingy', 'culver', 'amentulum', 'carberry', 'inconsequentially', 'cribellum', 'lacunulose', 'chargee', 'certiorari', 'museology', 'unquibbling', 'morphinomania', 'phenolsulphonate', 'lithologic', 'ferromagnetic', 'Pactolus', 'shaggily', 'prethoughtfulness', 'overstraiten', 'murderously', 'nondeportation', 'dialogist', 'Aten', 'sulforicinate', 'predisaster', 'sawbones', 'follis', 'portrayment', 'electrionic', 'apocalyptist', 'foundationless', 'pukeweed', 'veined', 'sittringy', 'omninescience', 'fatigable', 'aluminaphone', 'unmeaningness', 'steepletop', 'unteaming', 'warman', 'palaeocosmology', 'underroll', 'enshield', 'Malaclemys', 'coloclysis', 'routinary', 'tideful', 'tetel', 'cacophonical', 'Liriodendron', 'Phemie', 'Albertist', 'valiship', 'scutigerous', 'guacimo', 'petasus', 'haberdasheress', 'promoter', 'adaptor', 'axoplasm', 'Olpidium', 'Elasmotherium', 'perfectible', 'malic']

# %%
from pykhmernlp.corpus import km2km_dict

entries = km2km_dict('កក់ក្ដៅ')
print(entries)
# Output: [{'t_main': 'ក', 't_pron': '[ក]', 't_poly': '', 't_pos': 'ន.', 't_exp': '...', 't_exam': '...'}, ...]
# Out:
# [{'word': 'កក់ក្ដៅ', 'pronounce': '[កក់-ក្ដៅ]', 'pos': 'កិ.', 'definition': 'ក្ដៅល្មម ក្ដៅស្រួល :', 'example': 'ភួយនេះកក់ក្ដៅណាស់។'}, {'word': 'កក់ក្ដៅ', 'pronounce': '[កក់-ក្ដៅ]', 'pos': 'កិ., គុ.កិ.', 'definition': '(ព.ប្រ.) ពេញចិត្ត រីករាយ, សង្ឃឹម ជឿជាក់ ទុកចិត្ត :', 'example': 'ពូកក់ក្ដៅដោយក្មួយមានការងារធ្វើ, ទទួលស្វាគមន៍យ៉ាងកក់ក្ដៅ។'}, {'word': 'កក់ក្ដៅ', 'pronounce': '[កក់-ក្ដៅ]', 'pos': 'គុ.', 'definition': 'ដែលជឿជាក់ ដែលទុកចិត្ត :', 'example': 'គ្រួសារកក់ក្ដៅ។'}]

# %%
from pykhmernlp.corpus import en2en_dict

entries = en2en_dict('BooK')
print(entries)
# Output: [{'t_main': 'ក', 't_pron': '[ក]', 't_poly': '', 't_pos': 'ន.', 't_exp': '...', 't_exam': '...'}, ...]
# Out:
# [{'word': 'book', 'pos': 'n.', 'definition': 'A collection of sheets of paper, or similar material, blank, written, or printed, bound together; commonly, many folded and bound sheets containing continuous printing or writing.'}, {'word': 'book', 'pos': 'n.', 'definition': 'A composition, written or printed; a treatise.'}, {'word': 'book', 'pos': 'n.', 'definition': 'A part or subdivision of a treatise or literary work; as, the tenth book of "Paradise Lost."'}, {'word': 'book', 'pos': 'n.', 'definition': 'A volume or collection of sheets in which accounts are kept; a register of debts and credits, receipts and expenditures, etc.'}, {'word': 'book', 'pos': 'n.', 'definition': 'Six tricks taken by one side, in the game of whist; in certain other games, two or more corresponding cards, forming a set.'}, {'word': 'book', 'pos': 'v. t.', 'definition': 'To enter, write, or register in a book or list.'}, {'word': 'book', 'pos': 'v. t.', 'definition': 'To enter the name of (any one) in a book for the purpose of securing a passage, conveyance, or seat; as, to be booked for Southampton; to book a seat in a theater.'}, {'word': 'book', 'pos': 'v. t.', 'definition': 'To mark out for; to destine or assign for; as, he is booked for the valedictory.'}]

# %% [markdown]
# ## Address

# %%
from pykhmernlp.address import km_villages, km_commune, km_districts, km_provinces

# List all villages
all_villages = km_villages()
print(f"Size Villages : {len(all_villages)}")
print(f"List of villages: {all_villages}")

print("\n")
# List villages from a specific province
battambang_villages = km_villages('battambang')
print(f"Size Battambang's Villages : {len(battambang_villages)}")
print(f"List battambang's villages: {battambang_villages}")
# Out:
# Size Villages : 9202
# List of villages: ['ភូមិតស៊ូ', 'ភូមិខ្យង', 'ភូមិម៉ឺនរាជ', 'ភូមិបដិវត្ដន៍', 'ភូមិច្រាច់', 'ភូមិប្រមូលផ្ដុំ', 'ភូមិភ្ញាក់រលឹក', 'ភូមិកំពង់ពុទ្រា', 'ភូមិវាលបរ', 'ភូមិឆែបលិច', 'ភូមិឆែបកើត', 'ភូមិគុណភាពមួយ', 'ភូមិគុណភាពពីរ', 'ភូមិណារ៉ុង', 'ភូមិដងផ្លិត', 'ភូមិសាអែម', 'ភូមិកោឡោត', 'ភូមិសម្បូរ', 'ភូមិម្លូព្រៃ', 'ភូមិតុល', 'ភូមិពោធិទាប', 'ភូមិបុះ', 'ភូមិប្រើសក្អក', 'ភូមិកំពង់ស្រឡៅ', 'ភូមិកំពង់ពោធិ', 'ភូមិកំពង់សង្កែ', 'ភូមិខំាកឺត', 'ភូមិកំពង់សាមី', 'ភូមិកំពង់ព្រះឥន្ទ', 'ភូមិជាំក្សាន្ដ', 'ភូមិវាលពោធិ៍', 'ភូមិត្រពាំងសង្កែខាងកើត', 'ភូមិឈើទាលគង', 'ភូមិអានសេះ', 'ភូមិចាត់តាំង', 'ភូមិអូរក្សាន្ដ', 'ភូមិសែនរុងរឿង១', 'ភូមិសែនរុងរឿង៥', 'ភូមិត្មាតប៉ើយ', 'ភូមិរលំថ្ម', 'ភូមិត្រពាំងសង្កែខាងត្បូង', 'ភូមិដំណាក់កណ្តោល', 'ភូមិគង់យ៉ោង', 'ភូមិកំពាញ', 'ភូមិជាំអន្ទឹល', 'ភូមិជាំស្រែ', 'ភូមិស្រអែមខាងត្បូង', 'ភូមិត្រពាំងសង្កែខាងលិច', 'ភូមិមរកតតេជោ', 'ភូមិធម្មជាតិសម្ដេចតេជោ ហ៊ុន សែន', 'ភូមិស្រអែមខាងជើង', 'ភូមិតេជោបុស្សស្បូវ', 'ភូមិចំបក់សែនជ័យ', 'ភូមិស្ទឹងខៀវតេជោ', 'ភូមិបង្គោល៨', 'ភូមិរបុញ', 'ភូមិសែនតេជៈ', 'ភូមិតេជោមរកត', 'ភូមិសែនរុងរឿង២', 'ភូមិសែនរុងរឿង៣', 'ភូមិសែនរុងរឿង៤', 'ភូមិគូលែនត្បូង', 'ភូមិគូលែនជើង', 'ភូមិព្យួរជ្រូក', 'ភូមិត្រាវគៀត', 'ភូមិដាន', 'ភូមិស្របាល', 'ភូមិស្រឡៃ', 'ភូមិបរិបូណ៌', 'ភូមិក្ដាក់', 'ភូមិស្រយង់ជើង', 'ភូមិស្រយង់ត្បូង', 'ភូមិកោះកេរ', 'ភូមិម្រេច', 'ភូមិស្នាផ្អែក', 'ភូមិរវៀងជើង', 'ភូមិត្នោតម្លូ', 'ភូមិតាំងត្រក', 'ភូមិបាក់ក្ដោង', 'ភូមិដំណាក់ចិន', 'ភូមិតាតុង', 'ភូមិថ្កែង', 'ភូមិកំពត', 'ភូមិសង្កែរូង', 'ភូមិកក់ពោន', 'ភូមិចំឡង', 'ភូមិរវៀងត្បូង', 'ភូមិបុះពៃ', 'ភូមិឈ្នួន', 'ភូមិកេរ្ដ', 'ភូមិសំរិទ្ធិ', 'ភូមិសំព្រៀង', 'ភូមិស្លែងទោល', 'ភូមិបង្កន', 'ភូមិដូនម៉ា', 'ភូមិរំដោះ', 'ភូមិសន្លុងជ័យ', 'ភូមិពលកម្ម', 'ភូមិថ្នល់កោង', 'ភូមិស្វាយប៉ាត', 'ភូមិឪឡឹក', 'ភូមិត្រពាំងទទឹម', 'ភូមិអូរទ្រលោក', 'ភូមិបង្កើនផល', 'ភូមិស្វាយដំណាក់ចាស់', 'ភូមិស្វាយដំណាក់ថ្មី', 'ភូមិអូរពោរ', 'ភូមិជីឱក', 'ភូមិភ្នំដែក', 'ភូមិដា', 'ភូមិសែនគង់', 'ភូមិស្រីស្រណោះ', 'ភូមិអណ្ដូងភ្លូ', 'ភូមិស្ទឺង', 'ភូមិបឺង', 'ភូមិសុច', 'ភូមិត្រពាំងខ្ចែង', 'ភូមិតាសែងកណ្ដាល', 'ភូមិតាសែងជើង', 'ភូមិរលំស្លែង', 'ភូមិបាក់កាំ', 'ភូមិសេដ្ឋកិច្ច', 'ភូមិមហាផល', 'ភូមិស្រឡៅទូង', 'ភូមិពោធិ៍ខឿន', 'ភូមិប្រមេរុ', 'ភូមិស្រែព្រាង', 'ភូមិអណ្ដូងពោធិ', 'ភូមិទួលទំនប់', 'ភូមិហ្មសែត', 'ភូមិអូរខ្លែងពណ៌', 'ភូមិភារកិច្ច', 'ភូមិស្ថាពរ', 'ភូមិចំការស្រម៉ូវ', 'ភូមិម៉ាលិក', 'ភូមិកាតែ', 'ភូមិកាហល', 'ភូមិលោម', 'ភូមិកាជូត', 'ភូមិណាយ', 'ភូមិមុយ', 'ភូមិពែង', 'ភូមិចង', 'ភូមិតាង៉ា', 'ភូមិចាយ', 'ភូមិកែត', 'ភូមិតាំងជិ', 'ភូមិដាល', 'ភូមិតាំងសេ', 'ភូមិញ៉ាង', 'ភូមិតាឡាវ', 'ភូមិអ៊ីន', 'ភូមិកាណាត', 'ភូមិកាក់', 'ភូមិតាណង', 'ភូមិអូរមៀត', 'ភូមិឡូន', 'ភូមិសិល', 'ភូមិឡាប៉ូ', 'ភូមិជ្រី', 'ភូមិទេសអន្លុង', 'ភូមិភ្នំស្វាយ', 'ភូមិអូរកន្តិល', 'ភូមិលើតូច', 'ភូមិកាចក់', 'ភូមិយឺន', 'ភូមិលើហន់', 'ភូមិលើឃួន', 'ភូមិគ្រៀង', 'ភូមិទៀន', 'ភូមិប៉ាអរ', 'ភូមិប៉ាឡែ', 'ភូមិរ៉យ', 'ភូមិសាលាវ', 'ភូមិស៊ូ', 'ភូមិញ៉ល', 'ភូមិខ្មាំង', 'ភូមិភូមិមួយ', 'ភូមិលុងឃុង', 'ភូមិប៉ាយ៉ាង', 'ភូមិជ្រាក', 'ភូមិយ៉ាសោម', 'ភូមិស៊ើង', 'ភូមិចែត', 'ភូមិគ្លិ', 'ភូមិយ៉ែម', 'ភូមិទូយ', 'ភូមិកប', 'ភូមិលូត', 'ភូមិប៉ាណល', 'ភូមិស្រែពកធំ', 'ភូមិស្រែពកតូច', 'ភូមិនាងដី', 'ភូមិតាអងកាតេ', 'ភូមិតាអងប៉ុក', 'ភូមិទុស', 'ភូមិសិក', 'ភូមិតាកាប់', 'ភូមិតឺន', 'ភូមិឡាអិន', 'ភូមិតាហឺយ', 'ភូមិកាំបាក់', 'ភូមិអូរកាន', 'ភូមិសាមខា', 'ភូមិសាយ៉ស់', 'ភូមិកាឡែង', 'ភូមិកាណាងកិត', 'ភូមិកាំផ្លិញ', 'ភូមិកាទឹង', 'ភូមិកាទៀង', 'ភូមិកាលង', 'ភូមិកាចាញ', 'ភូមិអ៊ុល', 'ភូមិព្រួក', 'ភូមិបាតាង', 'ភូមិចាងរ៉ា', 'ភូមិប៉ា តត់', 'ភូមិកែងសាន់', 'ភូមិសាមុត្រលើ', 'ភូមិពម', 'ភូមិណងហៃ', 'ភូមិសាមុត្រក្រោម', 'ភូមិចាអ៊ុងកេត', 'ភូមិចាអ៊ុងចាន់', 'ភូមិធួយអំពិល', 'ភូមិធួយទុំ', 'ភូមិចាអ៊ុងកៅ', 'ភូមិម៉ាស', 'ភូមិកាន់ឈឺង', 'ភូមិក្រេះ', 'ភូមិតាង៉ាច', 'ភូមិខ្មែង', 'ភូមិកងកុយ', 'ភូមិប៉ាជន់ធំ', 'ភូមិអូម', 'ភូមិកាឡៃ ១', 'ភូមិកាឡៃ ២', 'ភូមិកាឡៃ ៣', 'ភូមិអូរជុំ', 'ភូមិថារ៉ងជង', 'ភូមិថារ៉ងស្វាយ', 'ភូមិល្អឺនក្រែន', 'ភូមិល្អឺនជង', 'ភូមិតងប្លេង', 'ភូមិតាកាម៉ាល់', 'ភូមិល្អឺនកាំងមីស', 'ភូមិកាម៉ែន', 'ភូមិប្រាក់', 'ភូមិបរញ៉ុក', 'ភូមិពីង', 'ភូមិក្រលង', 'ភូមិកាំ', 'ភូមិទុង', 'ភូមិដេះ', 'ភូមិប្លរ', 'ភូមិតាកុកព្នង', 'ភូមិតាកុកច្រាយ', 'ភូមិព្រិល', 'ភូមិឡែ', 'ភូមិកាទេ', 'ភូមិអ៊ុន', 'ភូមិប៉ក់ធំ', 'ភូមិប៉់ក់តូច', 'ភូមិប៉ក់ពោរ', 'ភូមិឡុំ', 'ភូមិប្លង់', 'ភូមិគងធំ', 'ភូមិគងយុ', 'ភូមិប៉ាតាង', 'ភូមិភិ', ' ...
#
#
# Size Battambang's Villages : 614
# List battambang's villages: ['ភូមិទួលធ្នង់', 'ភូមិស្វាយបីដើម', 'ភូមិសសរពក', 'ភូមិវត្ដកន្ទឺ', 'ភូមិប៉ុស្ដិកន្ទឺ', 'ភូមិចំការអូរ', 'ភូមិបាណន់', 'ភូមិកំប៉ង់លិច', 'ភូមិកំប៉់ង់កើត', 'ភូមិឆាយរំពាត់', 'ភូមិភ្នំគល់', 'ភូមិទួលច្រនៀង', 'ភូមិកំពង់ចែង', 'ភូមិកញ្ច្រោង', 'ភូមិក្រទ្បាពាស', 'ភូមិបាយដំរាំ', 'ភូមិតាស៊ង', 'ភូមិកំពង់ឆ្លង', 'ភូមិកំពង់ស្រមរ', 'ភូមិឥន្ទជិត', 'ភូមិបត់សាលា', 'ភូមិស្វាយប្រគាប', 'ភូមិឆកពោធិ៍៍', 'ភូមិអន្លង់តាម៉ី', 'ភូមិចំការស្វាយ', 'ភូមិបបុះ', 'ភូមិអន្លក់កោង', 'ភូមិចែង', 'ភូមិកំពង់គល់', 'ភូមិធ្ង័រ', 'ភូមិបុះខ្នុរ', 'ភូមិចង្ហូរស្វាយ', 'ភូមិចែងក្ដារ', 'ភូមិកំប៉ូវ', 'ភូមិភ្នំសំពៅលិច', 'ភូមិភ្នំសំពៅកើត', 'ភូមិសំណាញ់', 'ភូមិក្ដោង', 'ភូមិក្រពើជើង', 'ភូមិក្រពើត្បូង', 'ភូមិក្រពើកើត', 'ភូមិស្នឹងលិច', 'ភូមិស្នឹងកើត', 'ភូមិបឹងចែង', 'ភូមិបឹងប្រី', 'ភូមិពាក់ស្បែក', 'ភូមិព្រះស្រែ', 'ភូមិរំជៃ', 'ភូមិសំបួរមាស', 'ភូមិបឹងក្រសាល', 'ភូមិប៉ោយស្វាយ', 'ភូមិតាគ្រាម', 'ភូមិអូរពងមាន់', 'ភូមិតាង៉ែន', 'ភូមិអូរតាញា', 'ភូមិដង្គត់ធ្នង់', 'ភូមិអណ្ដូងនាង', 'ភូមិស្លាបប៉ាង', 'ភូមិថ្មគោលត្បូង', 'ភូមិប៉ោយយង់', 'ភូមិប៉ោយសំរោង', 'ភូមិគោកក្ដួច', 'ភូមិអង់ត្បូង', 'ភូមិទំពូងត្បូង', 'ភូមិថ្មគោលជើង', 'ភូមិគោកត្រប់', 'ភូមិតាសី', 'ភូមិជ្រោយម្ទេស', 'ភូមិអង់ជើង', 'ភូមិទំពូងជើង', 'ភូមិអូរតាគី', 'ភូមិពពាលខែ', 'ភូមិវាលទ្រា', 'ភូមិព្រៃដាច់', 'ភូមិជ្រៃថ្មី', 'ភូមិកគោ', 'ភូមិក្បាលខ្មោច', 'ភូមិហៃសាន', 'ភូមិអន្លង់រុន', 'ភូមិស្លាស្លាក់', 'ភូមិចបកាប់', 'ភូមិជ្រោយស្ដៅ', 'ភូមិនិគមក្រៅ', 'ភូមិនិគមក្នុង', 'ភូមិនិគមកណ្តាល', 'ភូមិបឹងព្រីង', 'ភូមិអូរញរ', 'ភូមិស្នួលកោង', 'ភូមិប៉ោយតាសេក', 'ភូមិកៀនកែស ១', 'ភូមិកៀនកែស ២', 'ភូមិគោកឃ្មុំ', 'ភូមិកណ្ដាលត្បូង', 'ភូមិកណ្ដាលជើង', 'ភូមិឆ្កែកូន', 'ភូមិបន្សាយត្រែង', 'ភូមិតាកយ', 'ភូមិព្រៃលាវ', 'ភូមិកោងកាង', 'ភូមិទួលតាសុខ', 'ភូមិបល្ល័ង្កក្រោម', 'ភូមិប្រគាប', 'ភូមិប៉ោយរំជៃ', 'ភូមិរូងជ្រៃ', 'ភូមិអូរតាគាំ ១', 'ភូមិអូរតាគាំ ២', 'ភូមិអូរតាគាំ ៣', 'ភូមិទួលតាឯក', 'ភូមិដង្កោទាប', 'ភូមិព្រែកព្រះស្ដេច', 'ភូមិព្រែកតាតន់', 'ភូមិ១៣ មករា', 'ភូមិអូរខ្ជាយ', 'ភូមិទ្បឥដ្ឋ', 'ភូមិនំក្រៀប', 'ភូមិបែកចានថ្មី', 'ភូមិចំការឫស្សី', 'ភូមិរំចេក ១', 'ភូមិរំចេក ២', 'ភូមិរំចេក ៣', 'ភូមិរំចេក ៤', 'ភូមិរំចេក ៥', 'ភូមិសូភី ១', 'ភូមិសូភី ២', 'ភូមិរតនៈ', 'ភូមិចំការសំរោង១', 'ភូមិចំការសំរោង២', 'ភូមិវត្ដលៀប', 'ភូមិវត្ដរំដួល', 'ភូមិផ្កាស្លា', 'ភូមិស្លាកែត', 'ភូមិដាំស្ពៃ', 'ភូមិជ្រៃកោង', 'ភូមិអូរតានប់', 'ភូមិតាព្រួច', 'ភូមិអូរម៉ាល់', 'ភូមិដាក់សសរ', 'ភូមិសាលាបាទ្បាត់', 'ភូមិគោកពន្លៃ', 'ភូមិវត្ដរកា', 'ភូមិកូនសេក', 'ភូមិអណ្ដូងព្រីង', 'ភូមិបឹងរាំង', 'ភូមិវត្ដគរ', 'ភូមិច្រាបក្រសាំង', 'ភូមិបល្ល័ង្គ', 'ភូមិខ្សាច់ពោយ', 'ភូមិដំណាក់ហ្លួង', 'ភូមិកំពង់សីមា', 'ភូមិអូរចារ', 'ភូមិព្រៃកូនសេក', 'ភូមិកាប់គោថ្មី', 'ភូមិអណ្ដូងចេញ', 'ភូមិអង់', 'ភូមិព្រែកមហាទេព', 'ភូមិកំពង់ក្របី', 'ភូមិ២០ ឧសភា', 'ភូមិកម្មករ', 'ភូមិបវេល ១', 'ភូមិដាច់ព្រ័ត្រ', 'ភូមិសង្កែវារ', 'ភូមិកំពង់ព្នៅ', 'ភូមិស្ទឹងដាច់', 'ភូមិស្ពានកណ្ដោល', 'ភូមិសាំងរាំង', 'ភូមិដូនអាវ', 'ភូមិសំរោងជ័យ', 'ភូមិព្រៃតាឡូញ', 'ភូមិព្រៃសង្ហា', 'ភូមិកោះរាម', 'ភូមិរូងអំពិល', 'ភូមិបល្ល័ង្កលើ', 'ភូមិខ្នាចរមាស', 'ភូមិបល្ល័ង្កមានជ័យ', 'ភូមិជ្រោយស្នា', 'ភូមិដូនញ៉ែម', 'ភូមិចំការ', 'ភូមិដូនអោក', 'ភូមិបឹងសំរោង', 'ភូមិល្វាចាស់', 'ភូមិតាហ៊ី', 'ភូមិតាម៉ាត', 'ភូមិមក្លឿ', 'ភូមិព្រៃខ្ពស់', 'ភូមិដង្កោពេន', 'ភូមិបឹងជំនាង', 'ភូមិក្បាលអាង', 'ភូមិដង្កោក្រម៉ាង', 'ភូមិសៀម', 'ភូមិស្ថាពរ1', 'ភូមិតាខៀវ', 'ភូមិបួរុន', 'ភូមិស្ថាពរ២', 'ភូមិបឹងសង្កែ', 'ភូមិបួជុំ', 'ភូមិបឹងអារ័ក្ស', 'ភូមិកូប', 'ភូមិបឹងស្នួល', 'ភូមិបឹងពពូល', 'ភូមិសួនស្លា', 'ភូមិសាន', 'ភូមិបួ', 'ភូមិទួលក្រសាំង', 'ភូមិតាហែន', 'ភូមិអន្លង់រៃ', 'ភូមិបឹងអន្លក់', 'ភូមិដំណាក់់ដង្កោ', 'ភូមិស្រះទឹក', 'ភូមិតាគត់', 'ភូមិត្រពាំងក្បាលស្វា', 'ភូមិប្របហឹប', 'ភូមិអូរដូនពៅ', 'ភូមិច្រាំងបាក់', 'ភូមិអន្លង់រាំង', 'ភូមិទំនប់តាកួន', 'ភូមិបួសង្គ្រាជ', 'ភូមិក្រពើសែសិប', 'ភូមិបឹងធុង', 'ភូមិសំណាងព្រះស្រី', 'ភូមិយុត្តិធម៌', 'ភូមិបឹងក្រឡ', 'ភូមិអូរឫស្សី', 'ភូមិបឹងប្រាំ', 'ភូមិជ័យជំនះ', 'ភូមិបវេល ២', 'ភូមិទំនប់ទឹក', 'ភូមិព្រៃទទឹង ១', 'ភូមិព្រៃទទឺង ២', 'ភូមិគោក', 'ភូមិស្លខ្លាញ់', 'ភូមិកំពង់ឆ្នាំង ១', 'ភូមិកំពង់ឆ្នាំង ២', 'ភូមិព្រែកតាច្រែង', 'ភូមិព្រែកនរិន្ទ', 'ភូមិស្ដី', 'ភូមិរហាលសួង', 'ភូមិដួងមា', 'ភូមិរាជដូនកែវ', 'ភូមិអន្សងសក', 'ភូមិព្រែកត្រប់', 'ភូមិសំរោងក្នុង', 'ភូមិកំពង់សំបួរ', 'ភូមិសំរោងស្នោ', 'ភូមិសំរោងអូរទ្រា', 'ភូមិសំរោងតាកុក', 'ភូមិព្រែកស្នោ', 'ភូមិព្រែក ...

# %% [markdown]
# ## Tokenizer

# %%
from pykhmernlp.tokenizer import khmercut


khmercut("ឃាត់ខ្លួនជនសង្ស័យ០៤នាក់ ករណីលួចខ្សែភ្លើង នៅស្រុកព្រៃនប់")
# => ['ឃាត់ខ្លួន', 'ជនសង្ស័យ', '០៤', 'នាក់', ' ', 'ករណី', 'លួច', 'ខ្សែភ្លើង', ' ', 'នៅ', 'ស្រុក', 'ព្រៃនប់']
# Out:
# ['ឃាត់ខ្លួន',
#  'ជនសង្ស័យ',
#  '០៤',
#  'នាក់',
#  ' ',
#  'ករណី',
#  'លួច',
#  'ខ្សែភ្លើង',
#  ' ',
#  'នៅ',
#  'ស្រុក',
#  'ព្រៃនប់']

# %% [markdown]
# ## Pronounce

# %%
from pykhmernlp.pronounce import pronounce

result1 = pronounce("សម្ដេចបវរធិបតី")
print(result1)
# => ['សំ', 'ដាច់', 'ប', 'វ៉', 'ធិ', 'ប៉ៈ', 'ដី']

result2 = pronounce("មករា")
print(result2)
# => ['មៈ', 'កៈ', 'រ៉ា']
# Out:
# ['សំ', 'ដាច់', 'ប', 'វ៉', 'ធិ', 'ប៉ៈ', 'ដី']
# ['មៈ', 'កៈ', 'រ៉ា']

# %% [markdown]
# ## Tha

# %%
from pykhmernlp.tha import (
    normalize,
    process_phone_numbers,
    process_urls,
    process_time,
    process_date,
    process_hashtags,
    process_ascii_lines,
    process_license_plate,
    process_cardinals,
    process_decimals,
    process_ordinals,
    process_currency,
    process_parenthesis,
    process_repeater
)

# Normalize
assert normalize("មិន\u200bឲ្យ") == "មិនឱ្យ"

# Phone Numbers
assert process_phone_numbers("010123123", chunk_size=2) == "0▁10▁12▁31▁23"
assert process_phone_numbers("010123123", chunk_size=3) == "0▁10▁123▁123"
assert process_phone_numbers("0961231234", chunk_size=3) == "0▁96▁123▁1234"

# URLs and emails
assert process_urls("example@gmail.com") == "example at g▁mail dot com"
assert process_urls("https://google.com") == "google dot com"
assert process_urls("http://google.com") == "google dot com"
assert process_urls("google.com") == "google dot com"
assert process_urls("google.gov.kh") == "google dot gov dot k▁h"
assert process_urls("google.com.kh") == "google dot com dot k▁h"

# Time
assert process_time("10:23AM") == "10 23▁A▁M"
assert process_time("10:23PM") == "10 23▁P▁M"
assert process_time("1:23PM") == "1 23▁P▁M"

# Date
assert process_date("2024-01-02") == "2024 01 02"
assert process_date("01-02-2034") == "01 02 2034"

# Hashtags
assert process_hashtags("Hello world #this_will_remove hello") == "Hello world  hello"
assert process_hashtags("Hello world #លុប hello") == "Hello world  hello"
assert process_hashtags("Hello world #លុប1234 hello") == "Hello world  hello"

# ASCII Lines
assert process_ascii_lines("Remove --- asdasd") == "Remove  asdasd"
assert process_ascii_lines("Remove\n###\nasdasd") == "Remove\n\nasdasd"

# Cambodia License Plate
assert process_license_plate("1A 1234") == "1 A 12▁34"
assert process_license_plate("1A 4444") == "1 A ការ៉េ4"

# Number - Cardinals
assert process_cardinals("1234") == "មួយពាន់▁ពីររយ▁សាមសិបបួន"
assert process_cardinals("1") == "មួយ"
assert process_cardinals("1▁2") == "មួយ▁ពីរ"
assert process_cardinals("-1") == "ដក▁មួយ"
assert process_cardinals("10") == "ដប់"
assert process_cardinals("15") == "ដប់ប្រាំ"
assert process_cardinals("100") == "មួយរយ"
assert process_cardinals("10000") == "មួយម៉ឺន"
assert process_cardinals("10000.234") == "មួយម៉ឺន.ពីររយ▁សាមសិបបួន"
assert process_cardinals("-10000.234") == "ដក▁មួយម៉ឺន.ពីររយ▁សាមសិបបួន"
assert process_cardinals("-10000,234") == "ដក▁មួយម៉ឺន,ពីររយ▁សាមសិបបួន"

# Number - Decimals
assert process_decimals("123.324") == "មួយរយ▁ម្ភៃបី▁ចុច▁បីរយ▁ម្ភៃបួន"
assert process_decimals("123.001") == "មួយរយ▁ម្ភៃបី▁ចុច▁សូន្យ▁សូន្យ▁មួយ"
assert process_decimals("-123.0012") == "ដក▁មួយរយ▁ម្ភៃបី▁ចុច▁សូន្យ▁សូន្យ▁ដប់ពីរ"
assert process_decimals("-123,0012") == "ដក▁មួយរយ▁ម្ភៃបី▁ក្បៀស▁សូន្យ▁សូន្យ▁ដប់ពីរ"

# Number - Ordinals
assert process_ordinals("5th") == "ទី▁ប្រាំ"
assert process_ordinals("3rd") == "ទី▁បី"
assert process_ordinals("1st") == "ទី▁មួយ"
assert process_ordinals("10th") == "ទី▁ដប់"
assert process_ordinals("10") == "10"

# Number - Currency
assert process_currency("$100.01") == "មួយរយដុល្លារ▁មួយសេន"
assert process_currency("$100") == "មួយរយ▁ដុល្លារ"
# assert process_currency("100$") == "មួយរយដុល្លារ"
# assert process_currency("100៛") == "មួយរយរៀល"
# assert process_currency("100.32៛") == "មួយរយ▁ចុច▁សាមសិបពីររៀល"
# assert process_currency("100.0032៛") == "មួយរយ▁ចុច▁សូន្យ▁សូន្យ▁សាមសិបពីររៀល"

# Parenthesis
assert process_parenthesis("Hello (this will be ignored) world") == "Hello world"

# Iteration Mark
def fake_tokenizer(_):
    return ["គាត់", "បាន", "ទៅ", "បន្តិច", "ម្ដង"]

assert process_repeater("គាត់បានទៅបន្តិចម្ដងៗហើយ", tokenizer=fake_tokenizer) == "គាត់បានទៅបន្តិចម្ដង▁បន្តិចម្ដងហើយ"

print("All tests passed!")
# Out:
# All tests passed!

# %%
from pykhmernlp.tha import process_currency

print(process_currency("100$"))
print(process_currency("100៛"))
print(process_currency("100.32៛"))
print(process_currency("100.0032៛"))
# Out:
# មួយរយ▁ដុល្លារ
# មួយរយ▁រៀល
# មួយរយចុចសាមសិបពីរ▁រៀល
# មួយរយចុចសាមសិបពីរ▁រៀល
